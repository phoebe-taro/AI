# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
#評估指標
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
x = np.linspace(0, 3, 20)
Y = np.exp(x)
X = x.ravel().reshape(-1, 1)
plt.scatter(X, Y, color='blue', label='Data Point') #
plt.legend()
plt.show()

# %%
model = LinearRegression()
model.fit(X, Y)
y_pred = model.predict(X)
print("R2 score：", r2_score(Y,y_pred))
print("MSE score：", mean_squared_error(Y,y_pred))
# Out:
# R2 score： 0.8668580445689823
# MSE score： 4.129467788903517

# %%
def r2_score_imp(y_true, y_pred):
    mean_true = np.mean(y_true)
    SSr = np.sum((y_true - y_pred) ** 2)
    SSt = np.sum((y_true - mean_true) ** 2)
    r2 = 1 - (SSr / SSt)
    return r2

def MSE_imp(y_true, y_pred):
    return np.square(np.subtract(y_true,y_pred)).mean()

# %%
plt.scatter(X, Y, color='blue', label='Data Point')
plt.plot(X, y_pred, color='red', linewidth=3, label='Linear regression model')
plt.legend()
plt.show()

# %%
data = {
    'Year': [1.2, 1.3, 1.5, 1.6, 2.1, 2.6, 2.8, 3.0, 3.5, 3.6, 3.7, 3.8, 4.0, 4.2, 4.7, 5.0, 5.1, 5.3, 5.5, 5.6, 5.7, 5.8, 5.9, 6.1, 6.5, 6.8, 7.0, 7.2, 7.6, 7.8, 8.0, 8.1, 8.3, 8.5, 8.7, 8.8, 9.0, 9.2, 9.4, 9.7, 9.8, 9.9, 10.2, 10.4, 10.8, 11.2, 11.6, 11.8, 12.2, 12.8, 13.0, 13.3, 13.7, 14.2, 14.3, 14.5, 14.6, 14.8],
    'Salary': [66000, 60000, 58000, 70000, 66000, 78000, 68000, 70000, 82000, 78000, 88000, 90000, 80000, 75000, 80000, 78000, 98000, 100000, 130000, 150000, 146000, 136000, 168000, 188000, 200000, 240000, 230000, 210000, 270000, 280000, 260000, 250000, 276000, 288000, 320000, 300000, 280000, 290000, 340000, 350000, 310000, 330000, 360000, 300000, 370000, 360000, 330000, 280000, 360000, 380000, 350000, 330000, 340000, 360000, 380000, 370000, 350000, 380000]
}

df = pd.DataFrame(data)
df
# Out:
#     Year  Salary
# 0    1.2   66000
# 1    1.3   60000
# 2    1.5   58000
# 3    1.6   70000
# 4    2.1   66000
# 5    2.6   78000
# 6    2.8   68000
# 7    3.0   70000
# 8    3.5   82000
# 9    3.6   78000
# 10   3.7   88000
# 11   3.8   90000
# 12   4.0   80000
# 13   4.2   75000
# 14   4.7   80000
# 15   5.0   78000
# 16   5.1   98000
# 17   5.3  100000
# 18   5.5  130000
# 19   5.6  150000
# 20   5.7  146000
# 21   5.8  136000
# 22   5.9  168000
# 23   6.1  188000
# 24   6.5  200000
# 25   6.8  240000
# 26   7.0  230000
# 27   7.2  210000
# 28   7.6  270000
# 29   7.8  280000
# 30   8.0  260000
# 31   8.1  250000
# 32   8.3  276000
# 33   8.5  288000
# 34   8.7  320000
# 35   8.8  300000
# 36   9.0  280000
# 37   9.2  290000
# 38   9.4  340000
# 39   9.7  350000
# 40   9.8  310000
# 41   9.9  330000
# 42  10.2  360000
# 43  10.4  300000
# 44  10.8  370000
# 45  11.2  360000
# 46  11.6  330000
# 47  11.8  280000
# 48  12.2  360000
# 49  12.8  380000
# 50  13.0  350000
# ...

# %%
numpy_data = df.to_numpy()
print(numpy_data)
# Out:
# [[1.20e+00 6.60e+04]
#  [1.30e+00 6.00e+04]
#  [1.50e+00 5.80e+04]
#  [1.60e+00 7.00e+04]
#  [2.10e+00 6.60e+04]
#  [2.60e+00 7.80e+04]
#  [2.80e+00 6.80e+04]
#  [3.00e+00 7.00e+04]
#  [3.50e+00 8.20e+04]
#  [3.60e+00 7.80e+04]
#  [3.70e+00 8.80e+04]
#  [3.80e+00 9.00e+04]
#  [4.00e+00 8.00e+04]
#  [4.20e+00 7.50e+04]
#  [4.70e+00 8.00e+04]
#  [5.00e+00 7.80e+04]
#  [5.10e+00 9.80e+04]
#  [5.30e+00 1.00e+05]
#  [5.50e+00 1.30e+05]
#  [5.60e+00 1.50e+05]
#  [5.70e+00 1.46e+05]
#  [5.80e+00 1.36e+05]
#  [5.90e+00 1.68e+05]
#  [6.10e+00 1.88e+05]
#  [6.50e+00 2.00e+05]
#  [6.80e+00 2.40e+05]
#  [7.00e+00 2.30e+05]
#  [7.20e+00 2.10e+05]
#  [7.60e+00 2.70e+05]
#  [7.80e+00 2.80e+05]
#  [8.00e+00 2.60e+05]
#  [8.10e+00 2.50e+05]
#  [8.30e+00 2.76e+05]
#  [8.50e+00 2.88e+05]
#  [8.70e+00 3.20e+05]
#  [8.80e+00 3.00e+05]
#  [9.00e+00 2.80e+05]
#  [9.20e+00 2.90e+05]
#  [9.40e+00 3.40e+05]
#  [9.70e+00 3.50e+05]
#  [9.80e+00 3.10e+05]
#  [9.90e+00 3.30e+05]
#  [1.02e+01 3.60e+05]
# ...

# %%
X = numpy_data[:,0]
print(X)
X = X.reshape(-1, 1)
print(X)
# Out:
# [ 1.2  1.3  1.5  1.6  2.1  2.6  2.8  3.   3.5  3.6  3.7  3.8  4.   4.2
#   4.7  5.   5.1  5.3  5.5  5.6  5.7  5.8  5.9  6.1  6.5  6.8  7.   7.2
#   7.6  7.8  8.   8.1  8.3  8.5  8.7  8.8  9.   9.2  9.4  9.7  9.8  9.9
#  10.2 10.4 10.8 11.2 11.6 11.8 12.2 12.8 13.  13.3 13.7 14.2 14.3 14.5
#  14.6 14.8]
# [[ 1.2]
#  [ 1.3]
#  [ 1.5]
#  [ 1.6]
#  [ 2.1]
#  [ 2.6]
#  [ 2.8]
#  [ 3. ]
#  [ 3.5]
#  [ 3.6]
#  [ 3.7]
#  [ 3.8]
#  [ 4. ]
#  [ 4.2]
#  [ 4.7]
#  [ 5. ]
#  [ 5.1]
#  [ 5.3]
#  [ 5.5]
#  [ 5.6]
#  [ 5.7]
#  [ 5.8]
#  [ 5.9]
#  [ 6.1]
#  [ 6.5]
#  [ 6.8]
#  [ 7. ]
#  [ 7.2]
#  [ 7.6]
#  [ 7.8]
#  [ 8. ]
#  [ 8.1]
#  [ 8.3]
#  [ 8.5]
#  [ 8.7]
#  [ 8.8]
#  [ 9. ]
#  [ 9.2]
#  [ 9.4]
#  [ 9.7]
#  [ 9.8]
#  [ 9.9]
#  [10.2]
#  [10.4]
#  [10.8]
#  [11.2]
#  [11.6]
#  [11.8]
#  [12.2]
#  [12.8]
#  [13. ]
#  [13.3]
#  [13.7]
#  [14.2]
#  [14.3]
#  [14.5]
#  [14.6]
#  [14.8]]

# %%
Y = numpy_data[:,1]
print(Y)
Y = Y.reshape(-1, 1)
print(Y)
# Out:
# [ 66000.  60000.  58000.  70000.  66000.  78000.  68000.  70000.  82000.
#   78000.  88000.  90000.  80000.  75000.  80000.  78000.  98000. 100000.
#  130000. 150000. 146000. 136000. 168000. 188000. 200000. 240000. 230000.
#  210000. 270000. 280000. 260000. 250000. 276000. 288000. 320000. 300000.
#  280000. 290000. 340000. 350000. 310000. 330000. 360000. 300000. 370000.
#  360000. 330000. 280000. 360000. 380000. 350000. 330000. 340000. 360000.
#  380000. 370000. 350000. 380000.]
# [[ 66000.]
#  [ 60000.]
#  [ 58000.]
#  [ 70000.]
#  [ 66000.]
#  [ 78000.]
#  [ 68000.]
#  [ 70000.]
#  [ 82000.]
#  [ 78000.]
#  [ 88000.]
#  [ 90000.]
#  [ 80000.]
#  [ 75000.]
#  [ 80000.]
#  [ 78000.]
#  [ 98000.]
#  [100000.]
#  [130000.]
#  [150000.]
#  [146000.]
#  [136000.]
#  [168000.]
#  [188000.]
#  [200000.]
#  [240000.]
#  [230000.]
#  [210000.]
#  [270000.]
#  [280000.]
#  [260000.]
#  [250000.]
#  [276000.]
#  [288000.]
#  [320000.]
#  [300000.]
#  [280000.]
#  [290000.]
#  [340000.]
# ...

# %%
plt.scatter(X, Y, color='blue', label='Data Point')
plt.legend()
plt.show()

# %%
np.random.seed(29)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
print("訓練資料為", len(X_train))
print("測試資料為",len(X_test))
# Out:
# 訓練資料為 46
# 測試資料為 12

# %%
plt.scatter(X_test, Y_test, color='blue', label='Testing Data Point')
plt.legend()
plt.show()

# %%
Salary_model = LinearRegression()
Salary_model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_pred = Salary_model.predict(X_test)
print("R2 score：", r2_score(Y_test,y_pred))
print("MSE score：", mean_squared_error(Y_test,y_pred))
# Out:
# R2 score： 0.8934952793156967
# MSE score： 1807692790.316825

# %%
plt.scatter(X_test, Y_test, color='blue', label='Testing Data Point')
plt.plot(X_test, y_pred, color='red', linewidth=3, label='Linear regression model')
plt.legend()
plt.show()
