# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
import random
def sigmoid(x):
    return 1 / (1 + np.exp(-x))
years_of_experience = np.round(np.random.uniform(1.0, 15.0, 100),1)
base_salary = 30000
salay_scale = 120000
salaries = base_salary + salay_scale * sigmoid(years_of_experience - 8)
data = pd.DataFrame({
    'years_of_experience': years_of_experience,
    'salary': salaries})
data
# Out:
#     years_of_experience         salary
# 0                  13.7  149599.823123
# 1                  11.8  147374.247488
# 2                   5.7   40934.755322
# 3                   2.1   30327.835292
# 4                   6.7   55699.802035
# ..                  ...            ...
# 95                 14.4  149800.943870
# 96                  6.0   44304.350643
# 97                  6.0   44304.350643
# 98                  1.2   30133.504324
# 99                  3.6   31455.412198
#
# [100 rows x 2 columns]

# %%
x = data['years_of_experience']
y = data['salary']
plt.scatter(x,y,color='blue',label='DataPoint')
plt.legend()
plt.show()

# %%
np.random.seed(29)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
print("訓練資料為", len(x_train))
print("測試資料為",len(x_test))
# Out:
# 訓練資料為 70
# 測試資料為 30

# %%
plt.scatter(x_test, y_test, color='blue', label='Testing Data Point')
plt.legend()
plt.show()

# %%
x_train = x_train.values.reshape(-1, 1)
x_test = x_test.values.reshape(-1, 1)
Salary_model = LinearRegression()
Salary_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = Salary_model.predict(x_test)
print("R2 score：", r2_score(y_test,y_pred))
print("MSE score：", mean_squared_error(y_test,y_pred))
# Out:
# R2 score： 0.9062493342233416
# MSE score： 253487006.5028863

# %%
plt.scatter(x_test, y_test, color='blue', label='Testing Data Point')
plt.plot(x_test, y_pred, color='red', linewidth=3, label='Linear regression model')
plt.legend()
plt.show()
